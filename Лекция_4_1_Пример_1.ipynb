# %% [markdown]
# <a href="https://colab.research.google.com/github/Nataliia-Shap/4-course-PatternRecognition/blob/main/%D0%9B%D0%B5%D0%BA%D1%86%D0%B8%D1%8F_4_1_%D0%9F%D1%80%D0%B8%D0%BC%D0%B5%D1%80_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Приклад 1. Байєсівський класифікатор**

# %%
import numpy as np
import random
from keras.datasets import mnist
# класифікатор та метрики
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# дані - зображення рукописних цифр
(X_train, y_train), (X_test, y_test) = mnist.load_data()
#виведемо на екран зображення
X_test_copy=X_test
n_images = X_test.shape[0]
n_rows=4
n_cols=5

for i in range(1,n_rows*n_cols+1):
    im_idx = random.randint(0,n_images-1)
    pixels=X_train[im_idx]
    plt.subplot(n_rows, n_cols, i)
    plt.imshow(pixels, cmap='gray')
    plt.axis('off')
plt.show()

# %% [markdown]
# # Створимо математичний опис образу. Подамо зображення у векторному вигляді:

# %%
num_pixels = X_train.shape[1] * X_train.shape[2]
X_train = X_train.reshape(X_train.shape[0], num_pixels).astype('float32')
X_test = X_test.reshape(X_test.shape[0], num_pixels).astype('float32')

# %% [markdown]
# # Навчимо байєсівський класифікатор та використаємо його

# %%
clf_nb = GaussianNB()
# навчимо модель
clf_nb.fit(X_train,y_train)
# зробимо класифікацію за допомогою навченою моделі
y_test_pred_nb = clf_nb.predict(X_test);
a_nb = accuracy_score(y_test, y_test_pred_nb);
print(a_nb)
# Out:
# 0.5558

# %% [markdown]
# # На екран результати класифікації

# %%
n_images = X_test_copy.shape[0]
n_rows=2
n_cols=3
for i in range(1,n_rows*n_cols+1):
  im_idx = random.randint(0,n_images-1)
  pixels=X_test_copy[im_idx]
  print(y_test_pred_nb[im_idx])
  plt.subplot(n_rows, n_cols, i)
  plt.imshow(pixels, cmap='gray')
  plt.axis('off')
plt.show()
# Out:
# 8
# 9
# 9
# 0
# 8
# 6
